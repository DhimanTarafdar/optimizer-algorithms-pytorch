# %% [markdown]
# <a href="https://colab.research.google.com/github/DhimanTarafdar/AAA/blob/main/Optimizers_Pytorch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Import Libraries**

# %%
import torch
import torch.nn as nn
import torch.optim as optim
model = nn.Linear(10,1)

# %% [markdown]
# # **SGD with Momentum**

# %%
# SGD with Momentum
optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.9)

# %% [markdown]
# # **NAG (Nesterov Accelerated Gradient)**

# %%
# NAG — nesterov=True enables lookahead gradient
optimizer = optim.SGD(model.parameters(), lr=0.01,
                       momentum=0.9, nesterov=True)

# %% [markdown]
# # **Adagrad**

# %%
# Adagrad — adapts lr per parameter based on history
optimizer = optim.Adagrad(model.parameters(), lr=0.01)

# %% [markdown]
# # **RMSprop**

# %%
# RMSprop — fixes Adagrad's shrinking lr problem
optimizer = optim.RMSprop(model.parameters(), lr=0.01, alpha=0.99)

# %% [markdown]
# # **Adam**

# %%
# Adam — momentum + RMSprop combined (most popular)
optimizer = optim.Adam(model.parameters(), lr=0.001,
                        betas=(0.9, 0.999))
